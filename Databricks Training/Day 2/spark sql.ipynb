# %%
# %sql
Create table acc_dev.alekhya.house_part as
select *,current_timestamp() as ingestion_date from parquet.`/Volumes/acc_dev/naval/raw/house-price.parquet`

# %%
# %sql
SELECT * FROM acc_dev.alekhya.house_part

# %%
# %sql
Create table acc_dev.alekhya.retail_orders_sparksql as
select * from json.`/Volumes/acc_dev/naval/raw/retail_orders.json`

# %%
# %sql
select * from acc_dev.alekhya.retail_orders_sparksql

# %%
# %sql
Create table acc_dev.alekhya.financial_dataset_sparksql as
select * from csv.`/Volumes/acc_dev/naval/raw/financial_dataset.csv`

# %%
# %sql
SELECT * FROM acc_dev.alekhya.financial_dataset_sparksql

# %%
# %sql
Create table acc_dev.alekhya.financial_dataset_sparksql_2 as
select * from read_files("/Volumes/acc_dev/naval/raw/financial_dataset.csv",format=>"csv")

# %%
# %sql
select * from acc_dev.alekhya.financial_dataset_sparksql_2
