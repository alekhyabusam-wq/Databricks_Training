# %% [markdown]
# Spark: Parallel Processing
# Data Structures RDD, Data Frame, DS
# Data Frame: Immutable (Cannot Change once Created)
# https://spark.apache.org/docs/latest/api/python/getting_started/quickstart_df.html

# %%
data=([(1,'a'),(2,'b'),(3,'c')])
schema="id int, name string"
df=spark.createDataFrame(data,schema)

# %%
df.show()

# %%
df.display()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df

# %%
df.show()

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df.show()

# %% [markdown]
# ###Reader API

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv", header=True, inferSchema=True)
df_sales.show()

# %%
df_sales.write.saveAsTable("acc_dev.alekhya.sales_py")

# %%
# %sql
select COUNT(*) from acc_dev.alekhya.sales_py

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv", header=True, inferSchema=True)
df_sales.show()
df_sales.write.mode("overwrite").saveAsTable("acc_dev.alekhya.sales_py")

# %%
(spark
 .read
 .csv("/Volumes/acc_dev/naval/raw/csv/sales.csv", header=True, inferSchema=True)
 .write
 .mode("overwrite")
 .saveAsTable("acc_dev.alekhya.sales_py"))

# %%
df_houseprice = spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")
df_houseprice.display()

# %%
df_houseprice.write.mode("overwrite").saveAsTable("acc_dev.alekhya.house_py")

# %%
# %sql
select COUNT(*) FROM acc_dev.alekhya.house_py

# %%
df_houseprice.write.mode("append").saveAsTable("acc_dev.alekhya.house_py")

# %%
# %sql
SELECT COUNT(*) FROM acc_dev.alekhya.house_py

# %%
df_retail_orders = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")

# %%
df_retail_orders.display()
