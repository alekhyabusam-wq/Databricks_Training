# %% [markdown]
# **Databricks Notebook**

# %%
print("hello")

# %%
# %sql
select 1+1

# %%
# %sql
create schema acc_dev.alekhya

# %%
# %sql
use catalog acc_dev;
use schema alekhya;
create table demo (id int primary key)

# %% [markdown]
# ![](/Volumes/acc_dev/alekhya/raw/Sample.png)
