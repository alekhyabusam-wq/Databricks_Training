# %%
data=([(1,'Virat'),(2,'Rohit')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.alekhya.cricket")

# %%
data=([(3,'Sachin'),(4,'Dhoni')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").saveAsTable("acc_dev.alekhya.cricket")

# %%
# %sql
select * from acc_dev.naval.cricket

# %%
data=([(5,'sky','All Rounder'),(6,'Shubnam','Batsman')])
schema="id int, name string, role string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").option("mergeSchema", "true").saveAsTable("acc_dev.alekhya.cricket")

# %%
df=spark.table("acc_dev.alekhya.cricket")

# %%
# %sql
select * from acc_dev.alekhya.cricket
