# %%
# %sql
GRANT CREATE TABLE ON SCHEMA acc_dev.alekhya_bronze TO `anuragrayabharapu@gmail.com`;

# %%
# %sql
select * from acc_dev.naval_gold.agg_heartrate

# %%
# %sql
SELECT mrn, name, MEAN(heartrate) avg_heartrate, DATE_TRUNC("DD", time) date
  FROM acc_dev.naval_silver.heartrate_device
  GROUP BY mrn, name, DATE_TRUNC("DD", time)

# %%
# %sql
select * from acc_dev.naval_silver.heartrate_device
