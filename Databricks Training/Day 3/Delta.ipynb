-- %%
%sql
use catalog acc_dev;
use schema alekhya;

-- %%
%sql
create table if not exists emp(id int, name string, city string)

-- %%
%sql desc extended emp

-- %%
%sql
insert into emp values (1,'Alekhya','Hyderabad')

-- %%
%sql
select * from emp

-- %%
%sql
insert into emp values (2,'Alekhya','Hyderabad');
insert into emp values (3,'Alekhya','Hyderabad');

-- %%
%sql
select * from emp

-- %%
%sql desc history emp

-- %%
%sql
desc detail emp

-- %%
%sql
create or replace table emp_v2 as
select * from emp version as of 2 --TimeTravel

-- %%
%sql
select * from emp_v2

-- %%
%sql
insert into acc_dev.naval.emp values (2,"Alekhya","Hyderabad")

-- %%
%sql
select * from acc_dev.naval.emp

-- %%
%sql
select * from acc_dev.naval.emp timestamp as of '2025-11-05T04:43:34.000+00:00'

-- %%
%sql
delete from acc_dev.alekhya.emp

-- %%
restore table emp to version as of 3

-- %%
%python
df1=spark.sql("select * from emp version as of 2")
