# %%
# %sql
select * from acc_dev.alekhya_bronze.sales

# %%
# %run "/Workspace/Users/alekhya.busam@gmail.com/Databricks Training/Day 3/(Clone) multi hop/includes"

# %%
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.naval_silver.sales_cleaned")

# %%
df=spark.table(f"{catalog}.{schema}.sales")

# %%
df.dropDuplicates().display()

# %%
df.dropDuplicates().dropna().display()

# %%
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.alekhya_silver.sales_cleaned")

# %%
# %sql
select * from acc_dev.alekhya_silver.sales_cleaned
