# %%
from pyspark.sql.functions import *

# %%
input_path="/Volumes/acc_dev/naval/raw/csv/"
file_name="sales"

# %%
# %sql
use catalog acc_dev;
create schema if not exists alekhya_bronze;
create schema if not exists alekhya_silver;
create schema if not exists alekhya_gold;

# %%
def new_col(df):
    return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_path"))

# %%
catalog="acc_dev"
schema="alekhya_bronze"
